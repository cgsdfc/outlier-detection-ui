# %%
from pyod.models.knn import KNN   # kNN detector
from pyod.utils.data import generate_data

# %%
contamination = 0.1  # percentage of outliers
n_train = 200  # number of training points
n_test = 0  # number of testing points

X_train, X_test, y_train, y_test = generate_data(
    n_train=n_train, n_test=n_test, contamination=contamination)

# %%
# train kNN detector
clf_name = 'KNN'
clf = KNN()
clf.fit(X_train)

# get the prediction labels and outlier scores of the training data
y_train_pred = clf.labels_  # binary labels (0: inliers, 1: outliers)
y_train_scores = clf.decision_scores_  # raw outlier scores

# get the prediction on the test data
y_test_pred = clf.predict(X_test)  # outlier labels (0 or 1)
y_test_scores = clf.decision_function(X_test)  # outlier scores

# it is possible to get the prediction confidence as well
y_test_pred, y_test_pred_confidence = clf.predict(X_test, return_confidence=True)  # outlier labels (0 or 1) and confidence in the range of [0,1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4832\42416423.py in <module>
#       9
#      10 # get the prediction on the test data
# ---> 11 y_test_pred = clf.predict(X_test)  # outlier labels (0 or 1)
#      12 y_test_scores = clf.decision_function(X_test)  # outlier scores
#      13
#
# d:\Users\fengcong\AppData\Local\Programs\Python\Python37\lib\site-packages\pyod\models\base.py in predict(self, X, return_confidence)
#     165
#     166         check_is_fitted(self, ['decision_scores_', 'threshold_', 'labels_'])
# --> 167         pred_score = self.decision_function(X)
#     168         prediction = (pred_score > self.threshold_).astype('int').ravel()
#     169
#
# d:\Users\fengcong\AppData\Local\Programs\Python\Python37\lib\site-packages\pyod\models\knn.py in decision_function(self, X)
#     238                                'threshold_', 'labels_'])
#     239
# --> 240         X = check_array(X)
#     241
#     242         # initialize the output score
#
# d:\Users\fengcong\AppData\Local\Programs\Python\Python37\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     806                 "Found array with %d sample(s) (shape=%s) while a"
#     807                 " minimum of %d is required%s."
# --> 808                 % (n_samples, array.shape, ensure_min_samples, context)
#     809             )
#     810
#
# ValueError: Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.

# %%
from pyod.utils.data import evaluate_print
# evaluate and print the results
print("\nOn Training Data:")
evaluate_print(clf_name, y_train, y_train_scores)
print("\nOn Test Data:")
evaluate_print(clf_name, y_test, y_test_scores)
# Out:
# On Training Data:
# KNN ROC:1.0, precision @ rank n:1.0
#
# On Test Data:
# KNN ROC:0.9067, precision @ rank n:0.9

# %%
from pyod.utils.example import visualize

# %%
visualize(clf_name, X_train, y_train, X_test, y_test, y_train_pred,
          y_test_pred, show_figure=True, save_figure=False)
